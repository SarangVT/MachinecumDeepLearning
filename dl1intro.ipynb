# %%
"""
1. High Data Required for Training
2. Powerful GPUs with more memory required for training.
3. More training time
4. Automated Feature Selection
5. Fast Predictability
6. No interpretability, reason behind the output is unknown, as it happens in hidden layers.
There is one input layer and output layer, the layers in between are hidden and process all data, lower layers inspect basic features and higher layers inspect features close to real-world.
Data Sets: 
Image Data: Microsoft COCO
Video: YouTube SM
Text: SQuad
Audio: Google Audioset
Kaggle
Hardware:
1. FPGA: Field Programmable Gate Arrays
2. ASIC: Application Specific Integrated Circuit
3. Edge TPU: Tensor Processing Unit
4. NPU: Neural Processing Unit
Framework:
TensorFlow+Keras : Google, Industry
PyTorch: Facebook, Research
Deep Learning Architectures:
1. Image Classification: ResNET
2. Text Classification: BERT
3. Image Segmentation: UNet
4. Image Translation: Pix2Pix
5. Object Detection: YOLO(You only Look Once)
6. Speech Recognition: WaveNET
Types of Neutral Networks:
Multi-Layer Perception: Specially in non-linear relationship, Supervised Learning
Convolutional Neural Network: Image Processing, Video Processing
Recurrent Neural Network: Example LSTM, Long-Short Term Memory, used in Natural Language Processing, used in Alexa, Google Now, Siri, Cortana.
Auto Encoders: Compressing Data
Generative Adverserial Networks(Ian GoodFellow: Research Scientist at Google Brain):
Difference in Neuron and Perceptron:
Neuron is complex, has neuroplasticity, processing mechanism and algorithm varies.
Weights: Feature Importance
Perceptron Model:
Input->Weights+bias->Vectorised Summation->Activation Function
Perceptron is a binary classifier, and divides its region in 2 parts.
Hence, it can classify just linear data or a type of linear data.
"""
# Out:
# '\n1. High Data Required for Training\n2. Powerful GPUs with more memory required for training.\n3. More training time\n4. Automated Feature Selection\n5. Fast Predictability\n6. No interpretability, reason behind the output is unknown, as it happens in hidden layers.\nThere is one input layer and output layer, the layers in between are hidden and process all data, lower layers inspect basic features and higher layers inspect features close to real-world.\nData Sets: \nImage Data: Microsoft COCO\nVideo: YouTube SM\nText: SQuad\nAudio: Google Audioset\nKaggle\nHardware:\n1. FPGA: Field Programmable Gate Arrays\n2. ASIC: Application Specific Integrated Circuit\n3. Edge TPU: Tensor Processing Unit\n4. NPU: Neural Processing Unit\nFramework:\nTensorFlow+Keras : Google, Industry\nPyTorch: Facebook, Research\nDeep Learning Architectures:\n1. Image Classification: ResNET\n2. Text Classification: BERT\n3. Image Segmentation: UNet\n4. Image Translation: Pix2Pix\n5. Object Detection: YOLO(You 
# ...

# %%
"""Perceptron Trick:
We on either side, measures the data points that whether it is correctly classified or not, if yes then no action if no then move line towards it.
"""
import numpy as np

def step(z):
    return 1 if z>0 else 0

def perceptron(X, y):
    X = np.insert(X, 0, 1, axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    for i in range(200):
        j = np.random.randint(0,100)
        y_pred = step(np.dot(X[j], weights))
        weights = weights + lr*(y[j]-y_pred)*X[j]
    return weights[0], weights[1:]

from sklearn.datasets import make_classification
X, y = make_classification(n_samples=100, n_features=2, n_informative=1, n_redundant=0, n_classes=2, n_clusters_per_class=1, random_state=41, hypercube=False, class_sep=10)
intercept_, coef_ = perceptron(X, y)

# %%
print(intercept_, coef_)
# Out:
# 0.8 [1.4644229  0.14670556]

# %%
import matplotlib.pyplot as plt
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])
plt.figure(figsize=(10,6))
x_input = np.linspace(-3,3,100)
y_input = x_input*m+b
plt.plot(x_input, y_input, color='red', linewidth=3)
plt.scatter(X[:,0], X[:,1], c=y, cmap='winter', s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
"""At last, Perception Trick is a type of Trick, firstly we cannot quantify its accuracy, then it may face problem in convergence in large and noisy datasets, as it may pick correct points only, or incorrect points leading to wastage of epochs.
So, we want a firm approach towards the problem.
We would use SGD, and Loss Function
"""
def perceptron(X, y):
    w1 = w2 =b =1
    lr = 0.01
    for j in range(5000):
        for i in range(X.shape[0]):
            z = w1*X[i][0] + w2*X[i][1] + b
            
            if z*y[i] < 0:
                w1 = w1 + lr*y[i]*X[i][0]
                w2 = w2 + lr*y[i]*X[i][1]
                b = b + lr*y[i]
    return w1, w2, b

# %%
w1, w2, b = perceptron(X, y)
m = -(w1/w2)
c = -(b/w2)
x_input = np.linspace(-3,3,200)
y_input = m*x_input + c

plt.figure(figsize=(10,6))
plt.plot(x_input, y_input, color='red', linewidth=3)
plt.scatter(X[:,0], X[:,1], c=y, cmap='winter', s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
"""Activation Functions:
1. Sigmoid Function: Deals with probability
2. Softmax: MultiClass
3. Step Function: Perception type, binary classification of -1 or 1

Loss Function:
1. Binary Cross Entropy(Log loss): Binary Class
2. Categorical Cross Entropy: MultiClass
3. Hinge Loss: We have implemented
"""
# Out:
# 'Activation Functions:\n1. Sigmoid Function: Deals with probability\n2. Softmax: MultiClass\n3. Step Function: Perception type, binary classification of -1 or 1\n\nLoss Function:\n1. Binary Cross Entropy(Log loss): Binary Class\n2. Categorical Cross Entropy: MultiClass\n3. Hinge Loss: We have implemented\n'
